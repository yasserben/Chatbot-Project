# %% [markdown]
# <div class="alert alert-success">
# <b>
# The goal of this notebook is to be able to transform the Minotour chat logs into a dataset that has nearly the same format as the  DSTC2 dataset, which is the one used by the Deeppavlov framework to create a goal-oriented chatbot.
# </b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>
# The first step is to import all the csv chat logs and concatenate them, then we will be able to delete all the columns we don't need, and clean our dataset.
# </b>
# </div>

# %%
import random
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <div class="alert alert-success">
# <b>
# Let's import all the csv files
# </b>
# </div>

# %%
data1 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2018-08.csv')
data2 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2018-09.csv')
data3 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2018-10.csv')
data4 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2018-11.csv')
data5 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2018-12.csv')
data6 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2019-01.csv')
data7 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2019-02.csv')
data8 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2019-03.csv')
data9 = pd.read_csv('C:\\Users\\Med Yasser\\Documents\\3A\\SPRING\\Project\\chat logs\\log_2019-04.csv')

# %% [markdown]
# <div class="alert alert-success">
# <b>
# We concatenate them along the index axis (all the csv files have the same columns)
# </b>
# </div>

# %%
concat_data = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9])
concat_data = concat_data[['user','intent','clean_message','response']]

# %% [markdown]
# <div class="alert alert-success">
# <b>
# We want to keep the following columns : intent, clean_message, response.<br>
# In order to make a dataset that looks like the DSTC2 dataset, we need to create a new column called act that will represent somehow the "act" of the chatbot according to the intent of the user sentence.
# </b>
# </div>

# %%
concat_data[:10]
# Out:
#                                     user                  intent  \
# 0   9cd817ac-4f43-f5c8-8311-986630b4eb63  Default Welcome Intent
# 2   9cd817ac-4f43-f5c8-8311-986630b4eb63                 abandon
# 3   1572e885-81bd-04e0-2901-82593cc20a28              find.event
# 4   2e24a315-3212-8206-ff78-2ddeaa5e2bc1  Default Welcome Intent
# 5   2e24a315-3212-8206-ff78-2ddeaa5e2bc1  Default Welcome Intent
# 6   1572e885-81bd-04e0-2901-82593cc20a28              find.event
# 13  5c384e65-8ce5-c60f-cfc9-5f1c8533a916  Default Welcome Intent
# 15  82f744c7-3b36-76c7-5956-a67e84ed2c77  Default Welcome Intent
# 17  82f744c7-3b36-76c7-5956-a67e84ed2c77                 abandon
# 18  efa53fe0-010a-17d3-5b70-3c23dea37a9a  Default Welcome Intent
#
#                                         clean_message  \
# 0                                                "Hi"
# 2                                              "stop"
# 3                             "find events in mocaco"
# 4                                                "Hi"
# 5                                                "hi"
# 6                             "find events in Monaco"
# 13                                               "Hi"
# 15                                               "Hi"
# 17  "quelle est la meilleure période pour skier à ...
# 18                                               "Hi"
#
#                                              response                     act
# 0   "Good day! Are you bored? My name is MinoTour ...  Default Welcome Intent
# 2                            "Ok how may I help you?"                 abandon
# 3                                 "What is the city?"              find.event
# 4   "Hey! This is nice to see you :) My name is Mi...  Default Welcome Intent
# 5   "Hi! My name is MinoTour :) What do you want t...  Default Welcome Intent
# 6                             "What is the datetime?"              find.event
# 13  "Good day! Are you bored? My name is MinoTour ...  Default Welcome Intent
# 15  "Greetings! My name is MinoTour and I'm here t...  Default Welcome Intent
# 17  "Bien sûr comment puis-je vous aider maintenan...                 abandon
# 18  "Greetings! My name is MinoTour and I'm here t...  Default Welcome Intent

# %%
print("We have %s different discussions." % len(concat_data.user.unique()))
# Out:
# We have 374 different discussions.

# %%
print("We have %s different intents." % len(concat_data.intent.unique()))
# Out:
# We have 28 different intents.

# %%
print("We have %s different clean_message." % len(concat_data.clean_message.unique()))
# Out:
# We have 2313 different clean_message.

# %%
print("We have %s different responses." % len(concat_data.response.unique()))
# Out:
# We have 143 different responses.

# %% [markdown]
# <div class="alert alert-success">
# <b>
# We can see that for the response column there is a value called "result_card", we can say say that it is a kind of API call to an external database, so to simplify things we are going to delete all the line that contains "result_card"
# </b>
# </div>

# %%
concat_data = concat_data[concat_data.response != "<result_card>"]

# %%
concat_data[:10]
# Out:
#                                     user                  intent  \
# 0   9cd817ac-4f43-f5c8-8311-986630b4eb63  Default Welcome Intent
# 2   9cd817ac-4f43-f5c8-8311-986630b4eb63                 abandon
# 3   1572e885-81bd-04e0-2901-82593cc20a28              find.event
# 4   2e24a315-3212-8206-ff78-2ddeaa5e2bc1  Default Welcome Intent
# 5   2e24a315-3212-8206-ff78-2ddeaa5e2bc1  Default Welcome Intent
# 6   1572e885-81bd-04e0-2901-82593cc20a28              find.event
# 13  5c384e65-8ce5-c60f-cfc9-5f1c8533a916  Default Welcome Intent
# 15  82f744c7-3b36-76c7-5956-a67e84ed2c77  Default Welcome Intent
# 17  82f744c7-3b36-76c7-5956-a67e84ed2c77                 abandon
# 18  efa53fe0-010a-17d3-5b70-3c23dea37a9a  Default Welcome Intent
#
#                                         clean_message  \
# 0                                                "Hi"
# 2                                              "stop"
# 3                             "find events in mocaco"
# 4                                                "Hi"
# 5                                                "hi"
# 6                             "find events in Monaco"
# 13                                               "Hi"
# 15                                               "Hi"
# 17  "quelle est la meilleure période pour skier à ...
# 18                                               "Hi"
#
#                                              response                     act
# 0   "Good day! Are you bored? My name is MinoTour ...  Default Welcome Intent
# 2                            "Ok how may I help you?"                 abandon
# 3                                 "What is the city?"              find.event
# 4   "Hey! This is nice to see you :) My name is Mi...  Default Welcome Intent
# 5   "Hi! My name is MinoTour :) What do you want t...  Default Welcome Intent
# 6                             "What is the datetime?"              find.event
# 13  "Good day! Are you bored? My name is MinoTour ...  Default Welcome Intent
# 15  "Greetings! My name is MinoTour and I'm here t...  Default Welcome Intent
# 17  "Bien sûr comment puis-je vous aider maintenan...                 abandon
# 18  "Greetings! My name is MinoTour and I'm here t...  Default Welcome Intent

# %% [markdown]
# <div class="alert alert-success">
# <b>
# Now We will create a new column called act so that it can represent somehow the "intent" of the response generated by the chatbot.
# The act we will of course be related to the intent of the user message, so we will crate a dictionary so that each intent of the user message corresponds to an act
# </b>
# </div>

# %%
concat_data["act"]=concat_data["intent"]
# Out:
# C:\Users\Public\MOOC\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
concat_data
# Out:
#                                     user                   intent  \
# 0   9cd817ac-4f43-f5c8-8311-986630b4eb63   Default Welcome Intent
# 2   9cd817ac-4f43-f5c8-8311-986630b4eb63                  abandon
# 3   1572e885-81bd-04e0-2901-82593cc20a28               find.event
# 4   2e24a315-3212-8206-ff78-2ddeaa5e2bc1   Default Welcome Intent
# 5   2e24a315-3212-8206-ff78-2ddeaa5e2bc1   Default Welcome Intent
# 6   1572e885-81bd-04e0-2901-82593cc20a28               find.event
# 13  5c384e65-8ce5-c60f-cfc9-5f1c8533a916   Default Welcome Intent
# 15  82f744c7-3b36-76c7-5956-a67e84ed2c77   Default Welcome Intent
# 17  82f744c7-3b36-76c7-5956-a67e84ed2c77                  abandon
# 18  efa53fe0-010a-17d3-5b70-3c23dea37a9a   Default Welcome Intent
# 19  4a33a4a5-68a5-8e22-2c7f-22cd7d19d167   Default Welcome Intent
# 20  4a33a4a5-68a5-8e22-2c7f-22cd7d19d167               find.event
# 22  4661ee68-f1b9-1dc2-d19c-1c102820ce51   Default Welcome Intent
# 23  4661ee68-f1b9-1dc2-d19c-1c102820ce51  Default Fallback Intent
# 24  4661ee68-f1b9-1dc2-d19c-1c102820ce51           leave.negative
# 25  4661ee68-f1b9-1dc2-d19c-1c102820ce51          find.restaurant
# 26  4661ee68-f1b9-1dc2-d19c-1c102820ce51          find.restaurant
# 27  4661ee68-f1b9-1dc2-d19c-1c102820ce51          find.restaurant
# 28  5c384e65-8ce5-c60f-cfc9-5f1c8533a916                  abandon
# 29  5c384e65-8ce5-c60f-cfc9-5f1c8533a916               find.event
# 30  4a33a4a5-68a5-8e22-2c7f-22cd7d19d167   Default Welcome Intent
# 31  5bb97dea-e708-1510-b84b-dc5cbb5d80e1   Default Welcome Intent
# 32  86c22d1f-e8a4-5084-00bc-9ac54912a489   Default Welcome Intent
# 33  86c22d1f-e8a4-5084-00bc-9ac54912a489  Default Fallback Intent
# 34  86c22d1f-e8a4-5084-00bc-9ac54912a489  Default Fallback Intent
# 35  31d858e4-017c-36da-ad56-18adbe235c63   Default Welcome Intent
# 36  86c22d1f-e8a4-5084-00bc-9ac54912a489  Default Fallback Intent
# 37  d8ed49df-eef4-4690-7d1b-8a4aff7d3e8e   Default Welcome Intent
# 38  4661ee68-f1b9-1dc2-d19c-1c102820ce51               find.event
# 42  d8ed49df-eef4-4690-7d1b-8a4aff7d3e8e               find.event
# ..                                   ...                      ...
# 30  e75957e3-be46-20f0-6849-8708ff24279b   Default Welcome Intent
# 33  357e95be-b180-7623-be86-58dee41948ce   Default Welcome Intent
# 34  fbba6acb-c422-5ca3-5569-db61ec3d7098   Default Welcome Intent
# 35  8d79eed2-1860-17b1-5445-77a1c28d3843   Default Welcome Intent
# 36  d6a318b1-5e7d-4392-300a-18b7ef84b1d1   Default Welcome Intent
# 38  419a15de-8ed5-709b-61d3-a35221b7a25b   Default Welcome Intent
# 39  d6a318b1-5e7d-4392-300a-18b7ef84b1d1  Default Fallback Intent
# 40  d6a318b1-5e7d-4392-300a-18b7ef84b1d1  Default Fallback Intent
# 43  8d79eed2-1860-17b1-5445-77a1c28d3843           leave.negative
# 44  8d79eed2-1860-17b1-5445-77a1c28d3843   Default Welcome Intent
# 49  7e60740e-250c-a045-13fe-774efc2935bb   Default Welcome Intent
# 51  d6a318b1-5e7d-4392-300a-18b7ef84b1d1   Default Welcome Intent
# 53  d6a318b1-5e7d-4392-300a-18b7ef84b1d1  Default Fallback Intent
# 60  d6a318b1-5e7d-4392-300a-18b7ef84b1d1   Default Welcome Intent
# 63  d6a318b1-5e7d-4392-300a-18b7ef84b1d1  Default Fallback Intent
# 66  cd718195-9223-4b92-67d2-838f635af271   Default Welcome Intent
# 67  cd718195-9223-4b92-67d2-838f635af271               find.event
# 70  017fd081-a585-1186-ceef-471bb11f6752   Default Welcome Intent
# 71  4532da44-8165-c6bb-e291-d7d8c1f128df   Default Welcome Intent
# 73  f60b6509-3e0b-e3fe-04e9-a4cc2334efcf   Default Welcome Intent
# 74  f60b6509-3e0b-e3fe-04e9-a4cc2334efcf  Default Fallback Intent
# 76  1c5b81cb-208f-861c-cc53-833638a91f4e   Default Welcome Intent
# 77  1c5b81cb-208f-861c-cc53-833638a91f4e   Default Welcome Intent
# 78  1c5b81cb-208f-861c-cc53-833638a91f4e  access_to_auron_station
# 80  0d23bb62-b348-ccbc-fdb0-95eeb042645f   Default Welcome Intent
# 81  0d23bb62-b348-ccbc-fdb0-95eeb042645f   Default Welcome Intent
# 82  0d23bb62-b348-ccbc-fdb0-95eeb042645f          find.restaurant
# 84  cf294311-f8ed-800d-89ea-17c570913a3d   Default Welcome Intent
# 85  d3f39e23-1576-0f6b-8a69-628632e5ef7a   Default Welcome Intent
# 86  d3f39e23-1576-0f6b-8a69-628632e5ef7a   Default Welcome Intent
#
#                                         clean_message  \
# 0                                                "Hi"
# 2                                              "stop"
# 3                             "find events in mocaco"
# 4                                                "Hi"
# 5                                                "hi"
# 6                             "find events in Monaco"
# 13                                               "Hi"
# 15                                               "Hi"
# 17  "quelle est la meilleure période pour skier à ...
# 18                                               "Hi"
# 19                                               "Hi"
# 20                              "find events in nice"
# 22                                               "Hi"
# 23                                           "eating"
# 24                                       "i'm hungry"
# 25                       "fin me a casher restaurant"
# 26                      "find me a casher restaurant"
# 27                             "find me a restaurant"
# 28                                             "stop"
# 29                       "find me an event nearby me"
# 30                                               "hi"
# 31                                               "Hi"
# 32                                  "Hey how are you"
# 33                                 "how can you help"
# 34                                                "?"
# 35                                               "hi"
# 36                                 "how can you help"
# 37                                               "hi"
# 38            "what will be the weather this evening"
# 42                   "find sports activity in cannes"
# ..                                                ...
# 30                                               "Hi"
# 33                                               "Hi"
# 34                                               "Hi"
# 35                                               "Hi"
# 36                                               "Hi"
# 38                                               "Hi"
# 39                                   "and in Cannes?"
# 40                                   "and this week?"
# 43                                             "stop"
# 44                                               "Hi"
# 49                                               "Hi"
# 51                                               "hi"
# 53                                      "this week ?"
# 60                                      "Hi Minotour"
# 63                                      "next month "
# 66                                               "Hi"
# 67              "What are good events this week-end?"
# 70                                               "Hi"
# 71                                               "Hi"
# 73                                               "Hi"
# 74                                 "lavender in Nice"
# 76                                               "Hi"
# 77                                            "Hello"
# 78  "I am angry where is the good restaurant for me."
# 80                                               "Hi"
# 81                                            "Hello"
# 82                      "Can you suggest halal food?"
# 84                                               "Hi"
# 85                                               "Hi"
# 86                                               "Hi"
#
#                                              response                      act
# 0   "Good day! Are you bored? My name is MinoTour ...   Default Welcome Intent
# 2                            "Ok how may I help you?"                  abandon
# 3                                 "What is the city?"               find.event
# 4   "Hey! This is nice to see you :) My name is Mi...   Default Welcome Intent
# 5   "Hi! My name is MinoTour :) What do you want t...   Default Welcome Intent
# 6                             "What is the datetime?"               find.event
# 13  "Good day! Are you bored? My name is MinoTour ...   Default Welcome Intent
# 15  "Greetings! My name is MinoTour and I'm here t...   Default Welcome Intent
# 17  "Bien sûr comment puis-je vous aider maintenan...                  abandon
# 18  "Greetings! My name is MinoTour and I'm here t...   Default Welcome Intent
# 19  "Hi! I'm pleased to meet you! My name is MinoT...   Default Welcome Intent
# 20                            "What is the datetime?"               find.event
# 22  "Good day! Are you bored? My name is MinoTour ...   Default Welcome Intent
# 23                                   "One more time?"  Default Fallback Intent
# 24                   "Wait let’s give it another try"           leave.negative
# 25                                "What is the city?"          find.restaurant
# 26                                "What is the city?"          find.restaurant
# 27                                "What is the city?"          find.restaurant
# 28  "Ok no problem I reinitialize your request! Ho...                  abandon
# 29                                "What is the city?"               find.event
# 30  "Hi! I'm pleased to meet you! My name is MinoT...   Default Welcome Intent
# 31  "Hi! My name is MinoTour :) What do you want t...   Default Welcome Intent
# 32  "Good day! Are you bored? My name is MinoTour ...   Default Welcome Intent
# 33                                   "One more time?"  Default Fallback Intent
# 34            "I missed what you said. Say it again?"  Default Fallback Intent
# 35  "Hi! I'm pleased to meet you! My name is MinoT...   Default Welcome Intent
# 36                                   "I missed that."  Default Fallback Intent
# 37  "Hey! This is nice to see you :) My name is Mi...   Default Welcome Intent
# 38                                "What is the city?"               find.event
# 42                            "What is the datetime?"               find.event
# ..                                                ...                      ...
# 30  "Hi! My name is Minotour I'm here to advice yo...   Default Welcome Intent
# 33  "Hi! My name is Minotour I'm here to advice yo...   Default Welcome Intent
# 34  "Good day! Are you bored? I can suggest you on...   Default Welcome Intent
# 35  "Hi! My name is Minotour I'm here to advice yo...   Default Welcome Intent
# 36  "Hello! My name is Minotour and I'm here to ad...   Default Welcome Intent
# 38  "Hello! My name is Minotour and I'm here to ad...   Default Welcome Intent
# 39            "I missed what you said. Say it again?"  Default Fallback Intent
# 40         "I didn't get that. Can you say it again?"  Default Fallback Intent
# 43  "Come on don’t give up on me yet. I can still ...           leave.negative
# 44  "Hi! My name is Minotour I'm here to advice yo...   Default Welcome Intent
# 49  "Hi! I'm pleased to meet you! My name is Minot...   Default Welcome Intent
# 51  "Hello! My name is Minotour and I'm here to ad...   Default Welcome Intent
# 53                          "Can you say that again?"  Default Fallback Intent
# 60  "Hello! My name is Minotour and I'm here to ad...   Default Welcome Intent
# 63                    "Sorry can you say that again?"  Default Fallback Intent
# 66  "Hi! I'm pleased to meet you! My name is Minot...   Default Welcome Intent
# 67                                "What is the city?"               find.event
# 70  "Greetings! My name is Minotour and I'm here t...   Default Welcome Intent
# 71  "Greetings! My name is Minotour and I'm here t...   Default Welcome Intent
# 73  "Hi! My name is Minotour I'm here to advice yo...   Default Welcome Intent
# 74                               "I didn't get that."  Default Fallback Intent
# 76  "Hello! My name is Minotour and I’m at your se...   Default Welcome Intent
# 77  "Greetings! My name is Minotour and I'm here t...   Default Welcome Intent
# 78              "Routes dégagées circulation normale"  access_to_auron_station
# 80  "Hello! My name is Minotour I can provide you ...   Default Welcome Intent
# 81  "Good day! Are you bored? My name is Minotour ...   Default Welcome Intent
# 82                                "What is the city?"          find.restaurant
# 84  "Good Day! My name is Minotour I can suggest y...   Default Welcome Intent
# 85  "Hello! My name is Minotour and I'm here to ad...   Default Welcome Intent
# 86  "Hi! I'm pleased to meet you! My name is Minot...   Default Welcome Intent
#
# [2281 rows x 5 columns]

# %%
dict_line = {}
dict_line["user_message"] = "bonjour"
dict_line["bot_message"] = "hola"
print(dict_line)
# dicto_line = {}
dictoo_line= dict.fromkeys(["user_message","bot_message"],None)
print(dictoo_line)
# Out:
# {'user_message': 'bonjour', 'bot_message': 'hola'}
# {'user_message': None, 'bot_message': None}

# %%
import json

def fill_dict(dico,t,i, t_b, a):
    dico["text"] = t
    dico["itents"] = i
    dico["text_bot"] = t_b
    dico["act"] = a

dialog_id = "9cd817ac-4f43-f5c8-8311-986630b4eb63"
for index,row in concat_data.iterrows(): 
    dict_line= dict.fromkeys(["text","intents","text_bot","act"],None)
    fill_dict(dict_line,row['clean_message'],row['intent'],row['response'],row['act'])
    if (row['user'] == dialog_id):
        with open('data10.json', 'a') as file:  
            json.dump(dict_line, file,ensure_ascii=False)
            file.write("\n")
    else:
        dialog_id = row['user']
        with open('data10.json', 'a') as file:
            file.write("\n")
            json.dump(dict_line, file,ensure_ascii=False)
            file.write("\n")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-158-a359fa8e7dab> in <module>()
#      13     if (row['user'] == dialog_id):
#      14         with open('data10.json', 'a') as file:
# ---> 15             json.dump(dict_line, file,ensure_ascii=False)
#      16             file.write("\n")
#      17     else:
#
# C:\Users\Public\MOOC\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     178     # a debuggability cost
#     179     for chunk in iterable:
# --> 180         fp.write(chunk)
#     181
#     182
#
# C:\Users\Public\MOOC\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 3-8: character maps to <undefined>
